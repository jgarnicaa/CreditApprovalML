# %% [markdown]
# ### Objetivo :
#  - El objetivo principal de este notebook es realizar el estudio sobre los valores ya numerizados para generar el label de aprobación del crédito teniendo en cuentas las variables del dataset

# %%
## Librerias
import pandas as pd

# %%
## Carga y visualización del dataset

df = pd.read_csv('../data_acquisition/general_num.csv')
df.head()
# Out:
#    Unnamed: 0       ID  CODE_GENDER  FLAG_OWN_CAR  FLAG_OWN_REALTY  \
# 0           0  5008804            1             1                1
# 1           1  5008805            1             1                1
# 2           2  5008806            1             1                1
# 3           3  5008808            0             0                1
# 4           4  5008809            0             0                1
#
#    CNT_CHILDREN  AMT_INCOME_TOTAL  NAME_INCOME_TYPE  NAME_EDUCATION_TYPE  \
# 0             0          427500.0                 4                    1
# 1             0          427500.0                 4                    1
# 2             0          112500.0                 4                    4
# 3             0          270000.0                 0                    4
# 4             0          270000.0                 0                    4
#
#    NAME_FAMILY_STATUS  ...  DAYS_BIRTH  DAYS_EMPLOYED  FLAG_MOBIL  \
# ...

# %%
df['target'] = 0
df.loc[df['STATUS'].isin([2, 3, 4, 5]), 'target'] = 1 ## Se toman los clientes morosos como "riesgosos"
df.drop(columns=['Unnamed: 0'], inplace=True)
df
# Out:
#             ID  CODE_GENDER  FLAG_OWN_CAR  FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0      5008804            1             1                1             0
# 1      5008805            1             1                1             0
# 2      5008806            1             1                1             0
# 3      5008808            0             0                1             0
# 4      5008809            0             0                1             0
# ...        ...          ...           ...              ...           ...
# 36452  5149828            1             1                1             0
# 36453  5149834            0             0                1             0
# 36454  5149838            0             0                1             0
# 36455  5150049            0             0                1             0
# 36456  5150337            1             0                1             0
#
#        AMT_INCOME_TOTAL  NAME_INCOME_TYPE  NAME_EDUCATION_TYPE  \
# ...

# %%
df.to_csv('../data_acquisition/target.csv')
